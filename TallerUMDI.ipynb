# %% [markdown]
# <img src="jupyter.png" align="right" style="width:100px">
# <img src="julia.png" align="left" style="width:100px">
# <h1><center><top> Taller UMDI Junio/2017  </top></center></h1>

# %%
ENV["PYTHON"] = ""
# Out:
# ""

# %%
using PyPlot

# %%
versioninfo()
# Out:
# Julia Version 0.6.0
# Commit 9036443 (2017-06-19 13:05 UTC)
# Platform Info:
#   OS: Linux (x86_64-pc-linux-gnu)
#   CPU: Intel(R) Core(TM) i7-6700HQ CPU @ 2.60GHz
#   WORD_SIZE: 64
#   BLAS: libopenblas (USE64BITINT DYNAMIC_ARCH NO_AFFINITY Haswell)
#   LAPACK: libopenblas64_
#   LIBM: libopenlibm
#   LLVM: libLLVM-3.9.1 (ORCJIT, skylake)

# %%
println("Hola Atmósfera")
# Out:
# Hola Atmósfera

# %%
1 + 2
# Out:
# 3

# %%
3*3
# Out:
# 9

# %%
li = ("β","α","ϕ")
# Out:
# ("β","α","ϕ")

# %%
typeof(li)
# Out:
# Tuple{String,String,String}

# %%
ra = rand(1000);

# %%
plot(ra)
xlabel("Index")
ylabel("Rand")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcf2b709dd8>)
# PyObject <matplotlib.text.Text object at 0x7fcf2b73a6a0>
