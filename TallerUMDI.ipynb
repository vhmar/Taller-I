# %% [markdown]
# <img src="jupyter.png" align="right" style="width:100px">
# <img src="julia.png" align="left" style="width:100px">
# <h1><center><top> Taller UMDI Junio/2017  </top></center></h1>

# %%
ENV["PYTHON"] = ""
# Out:
# ""

# %%
using PyPlot
# Out:
# INFO: Installing PyQt5 via Anaconda's /home/marv/anaconda3/bin/conda...
# Fetching package metadata .........
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /home/marv/anaconda3:
# #
# pyqt                      4.11.4                   py35_4

# %%
1+2
# Out:
# 3

# %%
5^2
# Out:
# 25

# %%
β =collect(0:.2:200);

# %%
β
# Out:
# 25

# %%
α = β + rand(length(β))*10;

# %%
plot(α)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f63a4831438>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f638c320748>
